# %%
from geopy.geocoders import Nominatim
import pandas as pd

#座標取得
geo_list = []
geo = pd.read_csv("geo_point.csv")
geolocator = Nominatim(user_agent="user-id")
for chimei in range(len(geo)):
    location = geolocator.geocode(geo.iloc[chimei,0]+",江東区")
    geo_list.append([location.address.split(",")[0],location.latitude, location.longitude])
df_list = pd.DataFrame(geo_list, columns=["地名","緯度","経度"])
df_list.to_csv("geo_loc_loc.csv", index=False, encoding="utf_8")

# %%
import folium
from branca.element import Figure
from openrouteservice import convert
import pandas as pd

line1 = pd.read_csv("geo_loc_loc.csv")

color_list = ["red", "blue", "green", "purple", "orange", "darkred", "lightred", "beige", "darkblue", "darkgreen", "cadetblue", "darkpurple", "white", "pink", "lightblue", "lightgreen", "gray", "black", "lightgray"]
 
points_a = []

for i in range(len(line1)):
    points_a.append([line1.iloc[i,1],line1.iloc[i,2]])

# %%
import folium
import openrouteservice
from branca.element import Figure
from openrouteservice import convert

key = "5b3ce3597851110001cf624804ffaeec7cd246038d01eb4d3a32f633"
client = openrouteservice.Client(key=key)

loc_place = []
for chimei in range(len(points_a)-1):
    p1 = points_a[chimei]
    p2 = points_a[chimei+1]
    p1r = tuple(reversed(p1))
    p2r = tuple(reversed(p2))
    mean_lat = (p1[0] + p2[0]) / 2
    mean_long = (p1[1] + p2[1]) / 2

    # 経路計算 (Directions V2)
    routedict = client.directions((p1r, p2r))
    geom = routedict["routes"][0]["geometry"]
    decoded = convert.decode_polyline(geom)
    for i in range(len(decoded["coordinates"])):
        loc_place.append(decoded["coordinates"][i])

# %%
# Load map centred on average coordinates
ave_lat = sum(p[0] for p in points_a)/len(points_a)
ave_lon = sum(p[1] for p in points_a)/len(points_a)
fig = Figure(width=800, height=400)
my_map = folium.Map(
    location=[ave_lat, ave_lon], 
    zoom_start=13
)

#add a markers 'a'
for each in range(len(points_a)-1):
    folium.Marker(
        location=points_a[each+1],
        popup=line1.iloc[each+1,0],
        icon = folium.Icon(color=color_list[1])
    ).add_to(my_map)

# add markers 'z'
folium.Marker(
    location=[line1.iloc[0,1],line1.iloc[0,2]],
    popup=line1.iloc[0,0]
).add_to(my_map)

    
# add lines
folium.PolyLine(points_a, color=color_list[1], weight=2.5, opacity=1).add_to(my_map)
 
fig.add_child(my_map)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2ca03d91a11645e2bfb85c02187af393 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2ca03d91a11645e2bfb85c02187af393&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2ca03d91a11645e2bfb85c02187af393 = L.map(
#                 &quot;map_2ca03d91a11645e2bfb85c02187af393&quot;,
#                 {
#                     center: [35.63244935, 139.78678377819293],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5991912ef35c031489d9dd68e8c0419c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2ca03d91a11645e2bfb85c02187af393);
#
#
#             var marker_404e8a9152f008d6e5107f90608806ce = L.marker(
#                 [35.6297628, 139.7939817],
#                 {}
#             ).addTo(map_2ca03d91a11645e2bfb85c02187af393);
#
#
#             var icon_eceb6e11613f578e8c6dfe7232126057 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_404e8a9152f008d6e5107f90608806ce.setIcon(icon_eceb6e11613f578e8c6dfe7232126057);
#
#
#         var popup_ff4c227d7d97805c830648f96799574a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f7d3af8ddc64aa599608f0436c3c2dc9 = $(`&lt;div id=&quot;html_f7d3af8ddc64aa599608f0436c3c2dc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東京国際展示場（東京ビッグサイト）&lt;/div&gt;`)[0];
#                 popup_ff4c227d7d97805c830648f96799574a.setContent(html_f7d3af8ddc64aa599608f0436c3c2dc9);
#
#
#
#         marker_404e8a9152f008d6e5107f90608806ce.bindPopup(popup_ff4c227d7d97805c830648f96799574a)
#         ;
#
#
#
#
#             var marker_abd8d7e8f2d8b23f1dd9137c8dd4e4fb = L.marker(
#                 [35.64938, 139.789728],
#                 {}
#             ).addTo(map_2ca03d91a11645e2bfb85c02187af393);
#
#
#             var icon_ba74cb3e41c175c937efbc32b50a7db0 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_abd8d7e8f2d8b23f1dd9137c8dd4e4fb.setIcon(icon_ba74cb3e41c175c937efbc32b50a7db0);
#
#
#         var popup_e6b4962a6e6e665d121f6d7409a48c4e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f47be1fb090e1b6a4f6635edc4a4dc8a = $(`&lt;div id=&quot;html_f47be1fb090e1b6a4f6635edc4a4dc8a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;チームラボ プラネッツ&lt;/div&gt;`)[0];
#                 popup_e6b4962a6e6e665d121f6d7409a48c4e.setContent(html_f47be1fb090e1b6a4f6635edc4a4dc8a);
#
#
#
#         marker_abd8d7e8f2d8b23f1dd9137c8dd4e4fb.bindPopup(popup_e6b4962a6e6e665d121f6d7409a48c4e)
#         ;
#
#
#
#
#             var marker_85eca7770f4cc6a5a28f68893533ecc2 = L.marker(
#                 [35.6196145, 139.7769402],
#                 {}
#             ).addTo(map_2ca03d91a11645e2bfb85c02187af393);
#
#
#             var icon_529f9b2377455207a00015e9a67bcf34 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_85eca7770f4cc6a5a28f68893533ecc2.setIcon(icon_529f9b2377455207a00015e9a67bcf34);
#
#
#         var popup_1d5d18a26e22444541e464e0ca6cbe94 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7981e18f3f540d3de958b2d181d0e4e4 = $(`&lt;div id=&quot;html_7981e18f3f540d3de958b2d181d0e4e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;日本科学未来館&lt;/div&gt;`)[0];
#                 popup_1d5d18a26e22444541e464e0ca6cbe94.setContent(html_7981e18f3f540d3de958b2d181d0e4e4);
#
#
#
#         marker_85eca7770f4cc6a5a28f68893533ecc2.bindPopup(popup_1d5d18a26e22444541e464e0ca6cbe94)
#         ;
#
#
#
#
#             var marker_aa7b2c784c1f4ea0455994392d638bc5 = L.marker(
#                 [35.6310401, 139.7864852127717],
#                 {}
#             ).addTo(map_2ca03d91a11645e2bfb85c02187af393);
#
#
#         var popup_05e0d2be3cf9e1a2aaf6991ed4259d7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6e6bb7ab2dd7cc99258f7ec7e00c9323 = $(`&lt;div id=&quot;html_6e6bb7ab2dd7cc99258f7ec7e00c9323&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;武蔵野大学有明キャンパス&lt;/div&gt;`)[0];

# %%
def reverse_lat_long(list_of_lat_long):
    return [(p[1], p[0]) for p in list_of_lat_long]

coord = reverse_lat_long(loc_place)
fig = Figure(width=800, height=400)

my_map1 = folium.Map(
    location=(mean_lat, mean_long),
    zoom_start=13
)

for each in range(len(points_a)-1):
    folium.Marker(
        location=points_a[each+1],
        popup=line1.iloc[each+1,0],
        icon = folium.Icon(color=color_list[1])
    ).add_to(my_map1)


folium.Marker(
    location=[line1.iloc[0,1],line1.iloc[0,2]],
    popup=line1.iloc[0,0]
).add_to(my_map1)

folium.vector_layers.PolyLine(coord, color=color_list[1], weight=2.5, opacity=1).add_to(my_map1)
fig.add_child(my_map1)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77ff3e5f4ddbbeea92006b8b456bb17c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77ff3e5f4ddbbeea92006b8b456bb17c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77ff3e5f4ddbbeea92006b8b456bb17c = L.map(
#                 &quot;map_77ff3e5f4ddbbeea92006b8b456bb17c&quot;,
#                 {
#                     center: [35.634497249999995, 139.7833341],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a1d596f6efca27d129005679b94e4d9d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77ff3e5f4ddbbeea92006b8b456bb17c);
#
#
#             var marker_900fb1b528b75d6db81d187381db4da4 = L.marker(
#                 [35.6297628, 139.7939817],
#                 {}
#             ).addTo(map_77ff3e5f4ddbbeea92006b8b456bb17c);
#
#
#             var icon_a6c4d04ffebccde2c024be34fd23c076 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_900fb1b528b75d6db81d187381db4da4.setIcon(icon_a6c4d04ffebccde2c024be34fd23c076);
#
#
#         var popup_2a5eff31c68c4ec0966f8cc95fbd7b79 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33b757e24ef3bb980e545df976855cb0 = $(`&lt;div id=&quot;html_33b757e24ef3bb980e545df976855cb0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東京国際展示場（東京ビッグサイト）&lt;/div&gt;`)[0];
#                 popup_2a5eff31c68c4ec0966f8cc95fbd7b79.setContent(html_33b757e24ef3bb980e545df976855cb0);
#
#
#
#         marker_900fb1b528b75d6db81d187381db4da4.bindPopup(popup_2a5eff31c68c4ec0966f8cc95fbd7b79)
#         ;
#
#
#
#
#             var marker_dff0ff9514076322998a9706e06cc85c = L.marker(
#                 [35.64938, 139.789728],
#                 {}
#             ).addTo(map_77ff3e5f4ddbbeea92006b8b456bb17c);
#
#
#             var icon_2e60108fce773c0b72f700da098a4f25 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_dff0ff9514076322998a9706e06cc85c.setIcon(icon_2e60108fce773c0b72f700da098a4f25);
#
#
#         var popup_928bbf7f7a7970a9962b9d24c5d88a8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_72ca58ab2323430d57a2bcb56a88d76f = $(`&lt;div id=&quot;html_72ca58ab2323430d57a2bcb56a88d76f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;チームラボ プラネッツ&lt;/div&gt;`)[0];
#                 popup_928bbf7f7a7970a9962b9d24c5d88a8e.setContent(html_72ca58ab2323430d57a2bcb56a88d76f);
#
#
#
#         marker_dff0ff9514076322998a9706e06cc85c.bindPopup(popup_928bbf7f7a7970a9962b9d24c5d88a8e)
#         ;
#
#
#
#
#             var marker_4ab8aa1d313a07394b806c9c905a60d6 = L.marker(
#                 [35.6196145, 139.7769402],
#                 {}
#             ).addTo(map_77ff3e5f4ddbbeea92006b8b456bb17c);
#
#
#             var icon_29c6095bf27e30d00ff90370ed64fef5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_4ab8aa1d313a07394b806c9c905a60d6.setIcon(icon_29c6095bf27e30d00ff90370ed64fef5);
#
#
#         var popup_507da67361ffc4b8ac0e3aa7a7d51cc0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6ae3bf1aae5eadfefd731e57bacf12b9 = $(`&lt;div id=&quot;html_6ae3bf1aae5eadfefd731e57bacf12b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;日本科学未来館&lt;/div&gt;`)[0];
#                 popup_507da67361ffc4b8ac0e3aa7a7d51cc0.setContent(html_6ae3bf1aae5eadfefd731e57bacf12b9);
#
#
#
#         marker_4ab8aa1d313a07394b806c9c905a60d6.bindPopup(popup_507da67361ffc4b8ac0e3aa7a7d51cc0)
#         ;
#
#
#
#
#             var marker_e30e694ae741a02c95be8b110e509728 = L.marker(
#                 [35.6310401, 139.7864852127717],
#                 {}
#             ).addTo(map_77ff3e5f4ddbbeea92006b8b456bb17c);
#
#
#         var popup_46885af8788b7321572059fbb43a91af = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bd08be61e964d02e8a9a516de390c4ab = $(`&lt;div id=&quot;html_bd08be61e964d02e8a9a516de390c4ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;武蔵野大学有明キャンパス&lt;/div&gt;`)[0];
