# %%
from geopy.geocoders import Nominatim
import pandas as pd

#座標取得
geo_list = []
geo = pd.read_csv("geo_point.csv")
geolocator = Nominatim(user_agent="user-id")
for chimei in range(len(geo)):
    location = geolocator.geocode(geo.iloc[chimei,0]+",江東区")
    geo_list.append([location.address.split(",")[0],location.latitude, location.longitude])
df_list = pd.DataFrame(geo_list, columns=["地名","緯度","経度"])
df_list.to_csv("geo_loc_pos.csv", index=False, encoding="utf_8")

# %%
import folium
from branca.element import Figure
from openrouteservice import convert
import pandas as pd

line1 = pd.read_csv("geo_loc_pos.csv")

color_list = ["red","green","purple","orange","darkred","lightred","beige","darkblue","darkgreen","cadetblue","darkpurple","white","pink","lightblue","lightgreen","gray","black","lightgray","blue"]
 
points_a = []

for i in range(len(line1)):
    points_a.append([line1.iloc[i,1],line1.iloc[i,2]])

# %%
import folium
import openrouteservice
from branca.element import Figure
from openrouteservice import convert

key = "5b3ce3597851110001cf624804ffaeec7cd246038d01eb4d3a32f633"
client = openrouteservice.Client(key=key)

loc_place = []
for chimei in range(len(points_a)-1):
    p1 = points_a[chimei]
    p2 = points_a[chimei+1]
    p1r = tuple(reversed(p1))
    p2r = tuple(reversed(p2))
    mean_lat = (p1[0] + p2[0]) / 2
    mean_long = (p1[1] + p2[1]) / 2

    # 経路計算 (Directions V2)
    routedict = client.directions((p1r, p2r),profile="foot-walking")
    geom = routedict["routes"][0]["geometry"]
    decoded = convert.decode_polyline(geom)
    for i in range(len(decoded["coordinates"])):
        loc_place.append(decoded["coordinates"][i])

# %%
import csv

datalist = []

with open("geo_loc_pos.csv", encoding="utf_8") as f:
    reader = csv.reader(f)
    line = [row for row in reader]

for i in range(len(line)-2):
    p1 = float(line[i+1][1]), float(line[i+1][2])
    for j in range(i,len(line)-2):
        p2 = float(line[j+2][1]), float(line[j+2][2])
        p1r = tuple(reversed(p1))
        p2r = tuple(reversed(p2))
        mean_lat = (p1[0] + p2[0]) / 2
        mean_long = (p1[1] + p2[1]) / 2

        # 経路計算 (Directions V2)
        routedict = client.directions((p1r, p2r),profile="foot-walking")
        
        
        geom = routedict["routes"][0]["geometry"]
        decoded = convert.decode_polyline(geom)

        datalist.append([i,j+1,float(routedict["routes"][0]["summary"]["duration"])])
    
df_list = pd.DataFrame(datalist, columns=["出発地点","行先","移動時間[s]"])
df_list.to_csv("geo_loc_loc_time.csv", index=False, encoding="utf_8")

# %%
# Load map centred on average coordinates
ave_lat = sum(p[0] for p in points_a)/len(points_a)
ave_lon = sum(p[1] for p in points_a)/len(points_a)
fig = Figure(width=800, height=400)
my_map = folium.Map(
    location=[ave_lat, ave_lon], 
    zoom_start=13
)

#add a markers 'a'
for each in range(len(points_a)-1):
    folium.Marker(
        location=points_a[each+1],
        popup=line1.iloc[each+1,0],
        icon = folium.Icon(color=color_list[0])
    ).add_to(my_map)

# add markers 'z'
folium.Marker(
    location=[line1.iloc[0,1],line1.iloc[0,2]],
    popup=line1.iloc[0,0]
).add_to(my_map)

    
# add lines
folium.PolyLine(points_a, color=color_list[0], weight=2.5, opacity=1).add_to(my_map)
 
fig.add_child(my_map)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2d51c423e4ee797eb922a0e7a9093e19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2d51c423e4ee797eb922a0e7a9093e19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2d51c423e4ee797eb922a0e7a9093e19 = L.map(
#                 &quot;map_2d51c423e4ee797eb922a0e7a9093e19&quot;,
#                 {
#                     center: [35.63244935, 139.78678377819293],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e45e63a2049a9c455ca0ac9f0cb6be0e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2d51c423e4ee797eb922a0e7a9093e19);
#
#
#             var marker_b52c473599990546f475ea7f50a6bb64 = L.marker(
#                 [35.6297628, 139.7939817],
#                 {}
#             ).addTo(map_2d51c423e4ee797eb922a0e7a9093e19);
#
#
#             var icon_b8a0f1e93029301afdc793e9a091a1b3 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b52c473599990546f475ea7f50a6bb64.setIcon(icon_b8a0f1e93029301afdc793e9a091a1b3);
#
#
#         var popup_42a82043e55e868e034c8027847c2b22 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_57f68cd9fc5e723f439f105c5da18864 = $(`&lt;div id=&quot;html_57f68cd9fc5e723f439f105c5da18864&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東京国際展示場（東京ビッグサイト）&lt;/div&gt;`)[0];
#                 popup_42a82043e55e868e034c8027847c2b22.setContent(html_57f68cd9fc5e723f439f105c5da18864);
#
#
#
#         marker_b52c473599990546f475ea7f50a6bb64.bindPopup(popup_42a82043e55e868e034c8027847c2b22)
#         ;
#
#
#
#
#             var marker_c70985681d731bb7c8b3fd31ad331ec5 = L.marker(
#                 [35.64938, 139.789728],
#                 {}
#             ).addTo(map_2d51c423e4ee797eb922a0e7a9093e19);
#
#
#             var icon_5ef6c352efe0717ebefe650511f4533c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_c70985681d731bb7c8b3fd31ad331ec5.setIcon(icon_5ef6c352efe0717ebefe650511f4533c);
#
#
#         var popup_339934f015d3714949e5b1e248830778 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd04da689d14af2d078872932d2cec1c = $(`&lt;div id=&quot;html_fd04da689d14af2d078872932d2cec1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;チームラボ プラネッツ&lt;/div&gt;`)[0];
#                 popup_339934f015d3714949e5b1e248830778.setContent(html_fd04da689d14af2d078872932d2cec1c);
#
#
#
#         marker_c70985681d731bb7c8b3fd31ad331ec5.bindPopup(popup_339934f015d3714949e5b1e248830778)
#         ;
#
#
#
#
#             var marker_85fa9479f88adecbe1500a20bfa392c6 = L.marker(
#                 [35.6196145, 139.7769402],
#                 {}
#             ).addTo(map_2d51c423e4ee797eb922a0e7a9093e19);
#
#
#             var icon_ed487ecbeee41b6e48e50f6388ed0eb8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_85fa9479f88adecbe1500a20bfa392c6.setIcon(icon_ed487ecbeee41b6e48e50f6388ed0eb8);
#
#
#         var popup_d5e48b566462e33b2f0090186f48aee1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5393ea2b9ad6a7c36d5ee1efee811feb = $(`&lt;div id=&quot;html_5393ea2b9ad6a7c36d5ee1efee811feb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;日本科学未来館&lt;/div&gt;`)[0];
#                 popup_d5e48b566462e33b2f0090186f48aee1.setContent(html_5393ea2b9ad6a7c36d5ee1efee811feb);
#
#
#
#         marker_85fa9479f88adecbe1500a20bfa392c6.bindPopup(popup_d5e48b566462e33b2f0090186f48aee1)
#         ;
#
#
#
#
#             var marker_d393b1a38fd6812c8a4ec735a184d329 = L.marker(
#                 [35.6310401, 139.7864852127717],
#                 {}
#             ).addTo(map_2d51c423e4ee797eb922a0e7a9093e19);
#
#
#         var popup_3de86664062ca3e4adacac31cb4aa031 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e78c75e8c2d6a8e880a8db2dcf5e05ff = $(`&lt;div id=&quot;html_e78c75e8c2d6a8e880a8db2dcf5e05ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;武蔵野大学有明キャンパス&lt;/div&gt;`)[0];

# %%
def reverse_lat_long(list_of_lat_long):
    return [(p[1], p[0]) for p in list_of_lat_long]

coord = reverse_lat_long(loc_place)
fig = Figure(width=800, height=400)

my_map1 = folium.Map(
    location=(mean_lat, mean_long),
    zoom_start=13
)

for each in range(len(points_a)-1):
    folium.Marker(
        location=points_a[each+1],
        popup=line1.iloc[each+1,0],
        icon = folium.Icon(color=color_list[0])
    ).add_to(my_map1)


folium.Marker(
    location=[line1.iloc[0,1],line1.iloc[0,2]],
    popup=line1.iloc[0,0]
).add_to(my_map1)

folium.vector_layers.PolyLine(coord, color=color_list[0], weight=2.5, opacity=1).add_to(my_map1)
fig.add_child(my_map1)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6d004a857167765c2b947a5475b33d15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6d004a857167765c2b947a5475b33d15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6d004a857167765c2b947a5475b33d15 = L.map(
#                 &quot;map_6d004a857167765c2b947a5475b33d15&quot;,
#                 {
#                     center: [35.634497249999995, 139.7833341],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72edd6b4826cec1f9769dad316d10119 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6d004a857167765c2b947a5475b33d15);
#
#
#             var marker_aa0cd09c85a0dd9cfee375e540a43582 = L.marker(
#                 [35.6297628, 139.7939817],
#                 {}
#             ).addTo(map_6d004a857167765c2b947a5475b33d15);
#
#
#             var icon_fb835652d19bc36da55c9ed44d5eb348 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_aa0cd09c85a0dd9cfee375e540a43582.setIcon(icon_fb835652d19bc36da55c9ed44d5eb348);
#
#
#         var popup_cc80642b34a98e3b5988c24e8d96d5b6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a72e4d42b92040f68453016dab0fae1a = $(`&lt;div id=&quot;html_a72e4d42b92040f68453016dab0fae1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;東京国際展示場（東京ビッグサイト）&lt;/div&gt;`)[0];
#                 popup_cc80642b34a98e3b5988c24e8d96d5b6.setContent(html_a72e4d42b92040f68453016dab0fae1a);
#
#
#
#         marker_aa0cd09c85a0dd9cfee375e540a43582.bindPopup(popup_cc80642b34a98e3b5988c24e8d96d5b6)
#         ;
#
#
#
#
#             var marker_88b9b44cd4a1daf2aba4f304d106d230 = L.marker(
#                 [35.64938, 139.789728],
#                 {}
#             ).addTo(map_6d004a857167765c2b947a5475b33d15);
#
#
#             var icon_0a3934d14ab55a5bf7133bac83723632 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_88b9b44cd4a1daf2aba4f304d106d230.setIcon(icon_0a3934d14ab55a5bf7133bac83723632);
#
#
#         var popup_eed137f8964125a13786680aee45e576 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ec1dedf074b4e4eca81d8b94792f2b5 = $(`&lt;div id=&quot;html_4ec1dedf074b4e4eca81d8b94792f2b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;チームラボ プラネッツ&lt;/div&gt;`)[0];
#                 popup_eed137f8964125a13786680aee45e576.setContent(html_4ec1dedf074b4e4eca81d8b94792f2b5);
#
#
#
#         marker_88b9b44cd4a1daf2aba4f304d106d230.bindPopup(popup_eed137f8964125a13786680aee45e576)
#         ;
#
#
#
#
#             var marker_593622061d80b40415cbc7ce853bea39 = L.marker(
#                 [35.6196145, 139.7769402],
#                 {}
#             ).addTo(map_6d004a857167765c2b947a5475b33d15);
#
#
#             var icon_1b1a1f2f7e9df682fd0215c461d8da61 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_593622061d80b40415cbc7ce853bea39.setIcon(icon_1b1a1f2f7e9df682fd0215c461d8da61);
#
#
#         var popup_b634d7e8de3b46c8d5c4f90aa3cf43e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5e799e7f0adb72451d845ac02d1feed1 = $(`&lt;div id=&quot;html_5e799e7f0adb72451d845ac02d1feed1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;日本科学未来館&lt;/div&gt;`)[0];
#                 popup_b634d7e8de3b46c8d5c4f90aa3cf43e0.setContent(html_5e799e7f0adb72451d845ac02d1feed1);
#
#
#
#         marker_593622061d80b40415cbc7ce853bea39.bindPopup(popup_b634d7e8de3b46c8d5c4f90aa3cf43e0)
#         ;
#
#
#
#
#             var marker_904ad585c87f40de7b52b298efbfba4c = L.marker(
#                 [35.6310401, 139.7864852127717],
#                 {}
#             ).addTo(map_6d004a857167765c2b947a5475b33d15);
#
#
#         var popup_ba2d14445bd9c97c7b7bab4919db9465 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b4a63a3a2aa00d42ee681d5072a92cfb = $(`&lt;div id=&quot;html_b4a63a3a2aa00d42ee681d5072a92cfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;武蔵野大学有明キャンパス&lt;/div&gt;`)[0];
